# %%
import os
import shutil

# Формируем список имен файлов для перемещения
name_file_what_need_sort = os.listdir(path = "C:/Users/KarpovM/Desktop/Sort")
# print (name_file_what_need_sort)

def seach_place_one(need_val, need_val_two):    
    way_list_file = 'W:/СИиЗП/1 Участок испытаний и измерений/1.1 Подстанции/Диагностика/МАСЛО/'
    list_file = [way_list_file + 'Восточный', way_list_file + 'Северный', way_list_file + 'Юго-Западный']
    for item in list_file:
        list_res = os.listdir(path = item)
        for list_res_name in list_res:
            if need_val == list_res_name:
                return (item + '/' + need_val + '/' + need_val_two)
            else:
                continue

# Дробим элементы списка по пробелу получаем ['Академическая', 'Т1', '03.07.18.jpg'] для дальнейшго поиска пример
for name_file in name_file_what_need_sort:
    PS_name = name_file.split(" ")
    need_val = PS_name[0]
    need_val_two = PS_name[1]
    wer = seach_place_one(need_val, need_val_two)
    print (wer)
    if (wer is not None ):         
        name_file_peren = 'C:/Users/KarpovM/Desktop/Sort/' + name_file
        print (name_file_peren)
        file_what_need_sort = wer
        print (file_what_need_sort)
        shutil.move(name_file_peren, file_what_need_sort)
                            
    
    
# import shutil
# name_file = 'C:/Users/KarpovM/Desktop/Sort/Авиатор Т2 22.06.18.jpg'
# file_what_need_sort = 'W:/СИиЗП/1 Участок испытаний и измерений/1.1 Подстанции/Диагностика/МАСЛО/Восточный'
# shutil.move(name_file, file_what_need_sort)    
    
    
    
#     for trans in PS_name:
#         if (trans == "Т or trans == "Т"  or trans == "Т" or trans == "Т" ):
            
#     PS_name[0]
#     vost_res = os.listdir(path = "W:/СИиЗП/1 Участок испытаний и измерений/1.1 Подстанции/Диагностика/МАСЛО/Восточный")
#     for item in vost_res:
#         if (item == PS_name[0]):
#             name_file
            
            
        
    
    
    
    
#     open W:\СИиЗП\1 Участок испытаний и измерений\1.1 Подстанции\Диагностика\МАСЛО\Восточный
#     open W:\СИиЗП\1 Участок испытаний и измерений\1.1 Подстанции\Диагностика\МАСЛО\Северный
#     open W:\СИиЗП\1 Участок испытаний и измерений\1.1 Подстанции\Диагностика\МАСЛО\Юго-Западный
    
#     print (PS_name)
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# W:/СИиЗП/1 Участок испытаний и измерений/1.1 Подстанции/Диагностика/МАСЛО/Юго-Западный/Отрадная/Т2
# C:/Users/KarpovM/Desktop/Sort/Отрадная Т2 03.07.18.jpg
# W:/СИиЗП/1 Участок испытаний и измерений/1.1 Подстанции/Диагностика/МАСЛО/Юго-Западный/Отрадная/Т2
# W:/СИиЗП/1 Участок испытаний и измерений/1.1 Подстанции/Диагностика/МАСЛО/Восточный/Панельная/Т1
# C:/Users/KarpovM/Desktop/Sort/Панельная Т1 25.06.18.jpg
# W:/СИиЗП/1 Участок испытаний и измерений/1.1 Подстанции/Диагностика/МАСЛО/Восточный/Панельная/Т1
# W:/СИиЗП/1 Участок испытаний и измерений/1.1 Подстанции/Диагностика/МАСЛО/Восточный/Панельная/Т2
# C:/Users/KarpovM/Desktop/Sort/Панельная Т2 25.06.18.jpg
# W:/СИиЗП/1 Участок испытаний и измерений/1.1 Подстанции/Диагностика/МАСЛО/Восточный/Панельная/Т2
# W:/СИиЗП/1 Участок испытаний и измерений/1.1 Подстанции/Диагностика/МАСЛО/Северный/Парниковая/РПН
# C:/Users/KarpovM/Desktop/Sort/Парниковая РПН Т1 22.06.18.jpg
# W:/СИиЗП/1 Участок испытаний и измерений/1.1 Подстанции/Диагностика/МАСЛО/Северный/Парниковая/РПН
# W:/СИиЗП/1 Участок испытаний и измерений/1.1 Подстанции/Диагностика/МАСЛО/Северный/Парниковая/РПН
# C:/Users/KarpovM/Desktop/Sort/Парниковая РПН Т2 22.06.18.jpg
# W:/СИиЗП/1 Участок испытаний и измерений/1.1 Подстанции/Диагностика/МАСЛО/Северный/Парниковая/РПН
# W:/СИиЗП/1 Участок испытаний и измерений/1.1 Подстанции/Диагностика/МАСЛО/Северный/Парниковая/Т1
# C:/Users/KarpovM/Desktop/Sort/Парниковая Т1 04.07.18.jpg
# W:/СИиЗП/1 Участок испытаний и измерений/1.1 Подстанции/Диагностика/МАСЛО/Северный/Парниковая/Т1
# W:/СИиЗП/1 Участок испытаний и измерений/1.1 Подстанции/Диагностика/МАСЛО/Северный/Парниковая/Т2
# C:/Users/KarpovM/Desktop/Sort/Парниковая Т2 04.07.18.jpg
# W:/СИиЗП/1 Участок испытаний и измерений/1.1 Подстанции/Диагностика/МАСЛО/Северный/Парниковая/Т2
# W:/СИиЗП/1 Участок испытаний и измерений/1.1 Подстанции/Диагностика/МАСЛО/Юго-Западный/Рулонная/Т1
# C:/Users/KarpovM/Desktop/Sort/Рулонная Т1 03.07.18.jpg
# W:/СИиЗП/1 Участок испытаний и измерений/1.1 Подстанции/Диагностика/МАСЛО/Юго-Западный/
# W:/СИиЗП/1 Участок испытаний и измерений/1.1 Подстанции/Диагностика/МАСЛО/Юго-Западный/Чкаловская/В
# C:/Users/KarpovM/Desktop/Sort/Чкаловская В 110 Т2 ф «А» 21.06.18.jpg
# W:/СИиЗП/1 Участок испытаний и измерений/1.1 Подстанции/Диагностика/МАСЛО/Юго-Западный/Чкаловская/В
# W:/СИиЗП/1 Участок испытаний и измерений/1.1 Подстанции/Диагностика/МАСЛО/Юго-Западный/Чкаловская/В
# C:/Users/KarpovM/Desktop/Sort/Чкаловская В 110 Т2 ф «В» 21.06.18.jpg
# W:/СИиЗП/1 Участок испытаний и измерений/1.1 Подстанции/Диагностика/МАСЛО/Юго-Западный/Чкаловская/В
# W:/СИиЗП/1 Участок испытаний и измерений/1.1 Подстанции/Диагностика/МАСЛО/Юго-Западный/Чкаловская/В
# C:/Users/KarpovM/Desktop/Sort/Чкаловская В 110 Т2 ф «С» 21.06.18.jpg
# W:/СИиЗП/1 Участок испытаний и измерений/1.1 Подстанции/Диагностика/МАСЛО/Юго-Западный/Чкаловская/В
# W:/СИиЗП/1 Участок испытаний и измерений/1.1 Подстанции/Диагностика/МАСЛО/Юго-Западный/Чкаловская/СВ
# C:/Users/KarpovM/Desktop/Sort/Чкаловская СВ 110 ф.«А» 22.06.18.jpg
# W:/СИиЗП/1 Участок испытаний и измерений/1.1 Подстанции/Диагностика/МАСЛО/Юго-Западный/Чкаловская/СВ
# W:/СИиЗП/1 Участок испытаний и измерений/1.1 Подстанции/Диагностика/МАСЛО/Юго-Западный/Чкаловская/Т1
# C:/Users/KarpovM/Desktop/Sort/Чкаловская Т1 04.07.18.jpg
# W:/СИиЗП/1 Участок испытаний и измерений/1.1 Подстанции/Диагностика/МАСЛО/Юго-Западный/Чкаловская/Т1
# W:/СИиЗП/1 Участок испытаний и измерений/1.1 Подстанции/Диагностика/МАСЛО/Юго-Западный/Чкаловская/Т1
# C:/Users/KarpovM/Desktop/Sort/Чкаловская Т1 21.06.18.jpg
# W:/СИиЗП/1 Участок испытаний и измерений/1.1 Подстанции/Диагностика/МАСЛО/Юго-Западный/Чкаловская/Т1
# W:/СИиЗП/1 Участок испытаний и измерений/1.1 Подстанции/Диагностика/МАСЛО/Юго-Западный/Чкаловская/Т2
# C:/Users/KarpovM/Desktop/Sort/Чкаловская Т2 04.07.18.jpg
# W:/СИиЗП/1 Участок испытаний и измерений/1.1 Подстанции/Диагностика/МАСЛО/Юго-Западный/Чкаловская/Т2
# W:/СИиЗП/1 Участок испытаний и измерений/1.1 Подстанции/Диагностика/МАСЛО/Юго-Западный/Чкаловская/Т2
# C:/Users/KarpovM/Desktop/Sort/Чкаловская Т2 21.06.18.jpg
# W:/СИиЗП/1 Участок испытаний и измерений/1.1 Подстанции/Диагностика/МАСЛО/Юго-Западный/Чкаловская/Т2

# %%
import shutil
name_file = 'C:/Users/KarpovM/Desktop/Sort/Академическая Т1 03.07.18.jpg'
file_what_need_sort = 'W:/СИиЗП/1 Участок испытаний и измерений/1.1 Подстанции/Диагностика/МАСЛО/Юго-Западный/Академическая/Т1'
shutil.move(name_file, file_what_need_sort)
# Out:
# 'W:/СИиЗП/1 Участок испытаний и измерений/1.1 Подстанции/Диагностика/МАСЛО/Юго-Западный/Академическая/Т1\\Академическая Т1 03.07.18.jpg'

# %%
import re

name_file_what_need_sort = os.listdir(path = "C:/Users/KarpovM/Desktop/Sort")
PS_name = name_file_what_need_sort[0].split(" ")
# print (PS_name)


   
def seach_trans (PS_name):
    for trans in PS_name:
        if (trans == "Т1" or trans == "Т2"  or trans == "Т3" or trans == "Т4" and trans != 'В'):
            print (trans)
        
       
            
seach_trans(PS_name)
# Out:
# Т3

# %%
# Модуль для поиска места по названию куда необходимо переместить файл
PS_name = 'Северная'

def seach_place(PS_name[0]):    
    way_list_file = 'W:/СИиЗП/1 Участок испытаний и измерений/1.1 Подстанции/Диагностика/МАСЛО/'
    list_file = [way_list_file + 'Восточный', way_list_file + 'Северный', way_list_file + 'Юго-Западный']
    for item in list_file:
        list_res = os.listdir(path = item)
        for list_res_name in list_res:
            if PS_name == list_res_name:
                seach_place = (item + '/' + PS_name)
    return seach_place
                            
seach_place(PS_name)                            
        
        
    

# vost_res = os.listdir(path = "W:/СИиЗП/1 Участок испытаний и измерений/1.1 Подстанции/Диагностика/МАСЛО/Восточный")
# for item in vost_res:
#         if (item == PS_name[0]):
# Out:
# 'W:/СИиЗП/1 Участок испытаний и измерений/1.1 Подстанции/Диагностика/МАСЛО/Северный/Северная'

# %%
import re
import os
import xlrd, xlwt

name_file_oil = '/23072018.xlsx'
way_file_oil = os.getcwd() + name_file_oil 
print(way_file_oil)
read_file_oil = xlrd.open_workbook(way_file_oil)

#выбираем активный лист
active_sheet = read_file_oil.sheet_by_index(0)
active_sheet_info = [active_sheet.row_values(rownum) for rownum in range(active_sheet.nrows)]
# print(active_sheet_info)

def seach_number_protokol(active_sheet_info):
    result = re.findall((r'Протокол\s+'), active_sheet_info)
    print(result)
# Out:
# C:\Users\KarpovM\lesson_4.2_(Anaconda_and_mathplotlib)\File_for_oil/23072018.xlsx
